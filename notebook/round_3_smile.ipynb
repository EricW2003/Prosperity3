# %%
import numpy as np
import random as rd
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
implied_volatilties = pd.read_csv("../notebook/implied_volatilities.csv", sep=";")
